# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyAB_QsjZviwHVJHyBCeTPiK8M1NOvSLcns')

# %%
import pprint as pp

# %%
import pickle

# %%
with open('routes_scraper/routes.txt','rb') as f:
    routes = pickle.load(f)

# %%
pp.pprint(routes)
# Out:
# {'P101_1': [[103.74325, 1.49519],
#             [103.74321, 1.49538],
#             [103.74319, 1.4954],
#             [103.74311, 1.49543],
#             [103.7427, 1.49536],
#             [103.742, 1.49519],
#             [103.74169, 1.49513],
#             [103.74189, 1.49416],
#             [103.74199, 1.49378],
#             [103.74132, 1.4935],
#             [103.74077, 1.49301],
#             [103.74064, 1.49278],
#             [103.74058, 1.49248],
#             [103.74071, 1.49204],
#             [103.74084, 1.49165],
#             [103.74084, 1.49165],
#             [103.74091, 1.49142],
#             [103.74089, 1.49083],
#             [103.7408, 1.49016],
#             [103.74072, 1.48982],
#             [103.74058, 1.48946],
#             [103.74039, 1.48886],
#             [103.74018, 1.48826],
#             [103.73997, 1.48779],
#             [103.73976, 1.48746],
#             [103.73931, 1.48688],
#             [103.73887, 1.48626],
# ...

# %%
result_map = gmaps.static_map(
                 scale=2, 
                 zoom=12,
                 format='jpg',
                 size=[640, 640],  
                 maptype="roadmap",
                 path="color:0x0000ff|weight:2|" + "|".join([f'{i[1]},{i[0]}' for i in routes['P101_1']]))

# %%
with open('route_map.jpg', 'wb') as img:
    for chunk in result_map:
        img.write(chunk)
